# %%
# %sql
CREATE  TABLE HouseSensor(house string,lastSensorEventHours integer, lastSensorEventSeconds integer, lastSensorDayOfWeek integer, windowDuration integer, timeSinceLastSensorEvent integer, prevDominantSensor1 integer, prevDominantSensor2 integer, lastSensorID integer, lastSensorLocation integer, lastMotionLocation integer, complexity double, activityChange double, areaTransitions integer, numDistinctSensors integer, sensorCount_Bathroom double, sensorCount_Bedroom double, sensorCount_Chair double, sensorCount_DiningRoom double, sensorCount_Hall double, sensorCount_Ignore double, sensorCount_Kitchen double, sensorCount_LivingRoom double, sensorCount_Office double, sensorCount_OutsideDoor double, sensorCount_WorkArea double, sensorElTime_Bathroom double, sensorElTime_Bedroom double,sensorElTime_Chair double, sensorElTime_DiningRoom double, sensorElTime_Hall double, sensorElTime_Ignore double, sensorElTime_Kitchen double, sensorElTime_LivingRoom double, sensorElTime_Office double, sensorElTime_OutsideDoor double, sensorElTime_WorkArea double, activity string)
ROW FORMAT SERDE
  'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe'
STORED AS INPUTFORMAT
  'org.apache.hadoop.mapred.TextInputFormat'
OUTPUTFORMAT
  'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
LOCATION
  '/user/hive/HouseSensorDB'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# File location and type
from pyspark.sql.functions import lit
file_location = "/FileStore/tables/houseFeatures/csh130_features.csv"
file_type = "csv"
# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. 
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)
df = df.withColumn("house",lit("130"))
display(df)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.createOrReplaceTempView("Data")
spark.sql("insert into  HouseSensor select house, lastSensorEventHours, lastSensorEventSeconds, lastSensorDayOfWeek, windowDuration, timeSinceLastSensorEvent, prevDominantSensor1, prevDominantSensor2, lastSensorID, lastSensorLocation, lastMotionLocation, complexity, activityChange, areaTransitions, numDistinctSensors, double(sensorCount_Bathroom) sensorCount_Bathroom, double(sensorCount_Bedroom) sensorCount_Bedroom, double(sensorCount_Chair) sensorCount_Chair, double(sensorCount_DiningRoom) sensorCount_DiningRoom, double(sensorCount_Hall) sensorCount_Hall, double(sensorCount_Ignore) sensorCount_Ignore, double(sensorCount_Kitchen) sensorCount_Kitchen, double(sensorCount_LivingRoom) sensorCount_LivingRoom, double(sensorCount_Office) sensorCount_Office, double(sensorCount_OutsideDoor) sensorCount_OutsideDoor, double(sensorCount_WorkArea) sensorCount_WorkArea, double(sensorElTime_Bathroom) sensorElTime_Bathroom, double(sensorElTime_Bedroom) sensorElTime_Bedroom, double(sensorElTime_Chair) sensorElTime_Chair, double(sensorElTime_DiningRoom) sensorElTime_DiningRoom, double(sensorElTime_Hall) sensorElTime_Hall, double(sensorElTime_Ignore)  sensorElTime_Ignore, double(sensorElTime_Kitchen) sensorElTime_Kitchen, double(sensorElTime_LivingRoom) sensorElTime_LivingRoom, double(sensorElTime_Office) sensorElTime_Office, double(sensorElTime_OutsideDoor) sensorElTime_OutsideDoor, double(sensorElTime_WorkArea) sensorElTime_WorkArea, activity from Data")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[43]: DataFrame[]</div>

# %%
# %sql
select count(*) from HouseSensor
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>10674596</td></tr></tbody></table></div>
